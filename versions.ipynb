# %%
def main():
    #add student 
    i =input("add student ? (y/n)")
    if i.lower() == y:
        add_student()

# %%
student_dict ={}
def add_student():
    name = input("The student name ") 
    add_sub=input("you want to add a subject ? (y/n) ")
    if add_student.lower() == 'y':
        add_subject()
        student_dict[name]=sub_dict
    
    
# subject name and grade 

sub_dict = {}

def add_subject():
    cont = True
    while cont:
       
        add_s = input("Enter the subject name: ")
        sub_g = input("Enter the subject grade: ")
        
        sub_dict[add_s] = sub_g

        resume = input("Do you want to add another subject? (y/n): ")
        
        if resume.lower() == 'n':
            cont = False 
    return sub_dict

add_subject()

# %%
student_dict = {}

def add_subject():
    sub_dict = {}  # Initialize sub_dict inside the function
    cont = True
    while cont:
        add_s = input("Enter the subject name: ")
        sub_g = input("Enter the subject grade: ")
        sub_dict[add_s] = sub_g
        resume = input("Do you want to add another subject? (y/n): ")
        if resume.lower() == 'n':
            cont = False
    return sub_dict

def add_student():
    con =True
    while (con):
        name = input("Enter the student name: (or ESC)")
        if name.lower() == "esc":
            break
        add_sub = input("Do you want to add a subject? (y/n): ")
        if add_sub.lower() == 'y':
            student_dict[name] = add_subject()  
        elif add_sub.lower() == 'n':
            con =False

# Add students and subjects
add_student()

# Print the final dictionary of students and their subjects
print(student_dict)

# %%
student_dict = {}

def add_subject():
    sub_dict = {}  
    cont = True
    while cont:
        add_s = input("Enter the subject name: ")
        sub_g = input("Enter the subject grade: ")
        sub_dict[add_s] = sub_g
        resume = input("Do you want to add another subject? (y/n): ")
        if resume.lower() == 'n':
            calc_grade()
            cont = False
    return sub_dict

def calc_grade():
    for student, subjects in student_dict.items():
        total_grade = 0
        sub_num = 0
        for grade in subjects.values():
            total_grade += grade
            sub_num += 1 
        student_grade = total_grade / sub_num 
        print(f"Average grade for {student}: {student_grade}")
        
def add_student():
    while True:
        name = input("Enter the student name (or type 'ESC' to stop): ")
        if name.lower() == "esc":
            break
        add_sub = input("Do you want to add a subject? (y/n): ")
        if add_sub.lower() == 'y':
            student_dict[name] = add_subject()  
        elif add_sub.lower() == 'n':
            break 


add_student()

print(student_dict)

# %%
stud_dict = {
    'ali': {'maths': 90, 'science': 78},
    'mohamed': {'maths': 88, 'science': 69}
}

for student, subjects in stud_dict.items():
    total_grade = 0
    sub_num = 0
    for grade in subjects.values():
        total_grade += grade
        sub_num += 1 
    student_grade = total_grade / sub_num 
    print(f"Average grade for {student}: {student_grade}")

# %%
student_dict = {}

def add_subject():
    sub_dict = {}  
    cont = True
    while cont:
        add_s = input("Enter the subject name: ")
        sub_g = int(input("Enter the subject grade: ")) 
        sub_dict[add_s] = sub_g
        resume = input("Do you want to add another subject? (y/n): ")
        if resume.lower() == 'n':
            cont = False
    return sub_dict

def calc_grade():
    for student, subjects in student_dict.items():
        total_grade = 0
        sub_num = 0
        for grade in subjects.values():
            total_grade += grade
            sub_num += 1 
        student_grade = total_grade / sub_num 
        print(f"Average grade for {student}: {student_grade}")
        if student_grade > highest_grade:
            highest_grade = student_grade
            top_student = student
    print(f"the top student : {top_student},his grade : {highest_grade}")

def add_student():
    while True:
        name = input("Enter the student name (or type 'ESC' to stop): ")
        if name.lower() == "esc":
            break
        add_sub = input("Do you want to add a subject? (y/n): ")
        if add_sub.lower() == 'y':
            student_dict[name] = add_subject()  
        elif add_sub.lower() == 'n':
            break

add_student()

calc_grade()

# %%
student_dict = {}

def add_subject():
    sub_dict = {}  
    cont = True
    while cont:
        add_s = input("Enter the subject name: ")
        sub_g = float(input("Enter the subject grade: ")) 
        sub_dict[add_s] = sub_g
        resume = input("Do you want to add another subject? (y/n): ")
        if resume.lower() == 'n':
            cont = False
    return sub_dict

def calc_grade():
    for student, subjects in student_dict.items():
        total_grade = 0
        sub_num = 0
        highest_grade=0
        for grade in subjects.values():
            total_grade += grade
            sub_num += 1 
            student_grade = total_grade / sub_num 
            print(f"Average grade for {student}: {student_grade}")
            if student_grade > highest_grade:
                highest_grade = student_grade
                top_student = student
    print(f"the top student : {top_student},his grade : {highest_grade}")

def add_student():
    while True:
        name = input("Enter the student name (or type 'ESC' to stop): ")
        if name.lower() == "esc":
            break
        add_sub = input("Do you want to add a subject? (y/n): ")
        if add_sub.lower() == 'y':
            student_dict[name] = add_subject()  
        elif add_sub.lower() == 'n':
            break

add_student()

calc_grade()
